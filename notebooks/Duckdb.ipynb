# %%
# !pip install duckdb
# Out:
# Requirement already satisfied: duckdb in /usr/local/lib/python3.12/dist-packages (1.3.2)

# %%
import duckdb

# %%
con = duckdb.connect(database=':memory:', read_only = False)

# %%
query = "select * from 'customers.csv'"

# %%
result = con.execute(query).fetchdf()

# %%
result.head()
# Out:
#    customer_id first_name last_name                        email  \
# 0         1001       John       Doe         john.doe@example.com
# 1         1002      Emily     Smith    emily.smith@example.co.uk
# 2         1003    Michael     Brown    michael.brown@example.com
# 3         1004     Sophia    Wilson  sophia.wilson@example.co.th
# 4         1005      David   Johnson    david.johnson@example.com
#
#            created_at created_date  status country
# 0 2024-01-15 08:23:45   2024-01-15  active      US
# 1 2024-02-10 14:12:30   2024-02-10  active      UK
# 2 2024-03-05 19:45:12   2024-03-05  active      US
# 3 2024-04-01 09:05:55   2024-04-01  active      TH
# 4 2024-06-20 11:30:00   2024-06-20  active      US

# %%
result.shape
# Out:
# (10, 8)

# %%
filname = "Titanic-Dataset.csv"

# %%
query=f"select * from '{filname}'"

# %%
titanic_result = con.execute(query).fetchdf()

# %%
titanic_result.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  None        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  None        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  None        S

# %%
titanic_result.shape
# Out:
# (891, 12)

# %%
query = "select * from 'orders.csv'"

# %%
order_result = con.execute(query).fetchdf()

# %%
order_result.head()
# Out:
#   order_id customer_id  amount order_date     status
# 0    O1001        C001   120.5 2024-01-15  completed
# 1    O1002        C001    75.0 2024-02-20  completed
# 2    O1003        C001    50.0 2024-03-05  cancelled
# 3    O1004        C002   200.0 2024-04-25  completed
# 4    O1005        C002   150.0 2024-05-01  completed

# %%
order_result.shape
# Out:
# (12, 5)

# %%
result.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'email', 'created_at',
#        'created_date', 'status', 'country'],
#       dtype='object')

# %%
query = """
select
  customers_id,
  first_name,
  last_name,
  email,
  created_date
from 'customers.csv'
where status = 'active'
  and created_date >= '2024-01-01'
  and country = 'TH'
"""

# %%
customer_result2 = con.execute(query).fetchdf()
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# /tmp/ipython-input-166940781.py in <cell line: 0>()
# ----> 1 customer_result2 = con.execute(query).fetchdf()
#
# BinderException: Binder Error: Referenced column "customers_id" not found in FROM clause!
# Candidate bindings: "customer_id", "country", "last_name", "status", "first_name"
#
# LINE 3:   customers_id,
#           ^

# %%
customer_result2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4096943432.py in <cell line: 0>()
# ----> 1 customer_result2.head()
#
# NameError: name 'customer_result2' is not defined

# %%
query = """
select
  PassengerID,
  Name,
  Age,
  Fare,
  case
    when Survived = 1 then 'Survived'
    else 'Not Survived'
  end as Survived_status
from 'Titanic-Dataset.csv'
"""

# %%
tranfromed_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-598896170.py in <cell line: 0>()
# ----> 1 tranfromed_data.head()
#
# NameError: name 'tranfromed_data' is not defined

# %%
query = "select * from 'orders.csv'"

order_result = con.execute(query).fetchdf()

order_result.columns
# Out:
# Index(['order_id', 'customer_id', 'amount', 'order_date', 'status'], dtype='object')

# %%
query = "select * from 'orders.csv'"

order_result = con.execute(query).fetchdf()

order_result.columns
# Out:
# Index(['order_id', 'customer_id', 'amount', 'order_date', 'status'], dtype='object')

# %%
query = """
select
  c.customer_id,
  c.customer_name,
  c.segment,
  count(distinct o.order_id) as order_count,
  sum(o.amount) as total_amount
  avg(o.amount) as avg_amount
from 'new_customers.csv' c
left join 'order.csv'
  on c.customer_id = o.customer_id
  and o.status != 'cancelled'
  where c.is_active = true
  group by 1.2.3
"""
